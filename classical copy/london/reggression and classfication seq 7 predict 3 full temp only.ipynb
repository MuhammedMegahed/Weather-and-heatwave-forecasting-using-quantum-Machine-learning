# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
df_half_hour=pd.read_csv('EGLL.csv')
df_half_hour.isna().sum()
# Out:
# valid        0
# tmpf        73
# dwpf        80
# relh       166
# drct     17701
# alti     17443
# vsby        88
# feel       176
# dtype: int64

# %%
filter_df=df_half_hour
filter_df
# Out:
#                    valid   tmpf   dwpf   relh   drct   alti   vsby   feel
# 0          1/1/2010 0:00  34.00  29.00  81.57   20.0    NaN  17.00  27.19
# 1          1/1/2010 0:20  33.80  28.40  80.36   20.0  29.56   6.21  26.97
# 2          1/1/2010 0:50  33.80  28.40  80.36   10.0  29.56   6.21  28.53
# 3          1/1/2010 1:00  33.62  29.12  83.36   10.0    NaN  14.00  27.48
# 4          1/1/2010 1:20  33.80  28.40  80.36  360.0  29.56   6.21  26.97
# ...                  ...    ...    ...    ...    ...    ...    ...    ...
# 276526  10/20/2024 21:50  57.20  51.80  82.12  220.0  29.94   6.21  57.20
# 276527  10/20/2024 22:20  57.20  50.00  76.82  230.0  29.94   6.21  57.20
# 276528  10/20/2024 22:50  57.20  50.00  76.82  220.0  29.97   6.21  57.20
# 276529  10/20/2024 23:20  57.20  50.00  76.82  210.0  29.97   6.21  57.20
# 276530  10/20/2024 23:50  55.40  50.00  81.99  210.0  30.00   6.21  55.40
#
# [276531 rows x 8 columns]

# %%
# Ensure the 'valid' column is in datetime format
filter_df['valid'] = pd.to_datetime(filter_df['valid'])

# Add a 'date' column with full datetime (not just date) to support filtering
filter_df['date'] = filter_df['valid']

# Find rows with the maximum temperature for each day
daily_max_temp = filter_df.loc[filter_df.groupby(filter_df['date'].dt.date)['tmpf'].idxmax()].reset_index(drop=True)

# Define filtering range as pandas Timestamp for compatibility
start_date = pd.to_datetime('2010-01-01')
end_date = pd.to_datetime('2024-10-21')

# Filter the DataFrame based on datetime
filtered_df = daily_max_temp[(daily_max_temp['date'] >= start_date) & (daily_max_temp['date'] <= end_date)]

# Drop the 'valid' column as needed
filtered_df.drop(columns=['valid'], inplace=True)

# Final result
filtered_df
# Out:
#        tmpf   dwpf   relh   drct   alti   vsby   feel                date
# 0     38.12  25.52  60.14  340.0    NaN  17.00  32.90 2010-01-01 14:00:00
# 1     41.00  30.20  65.16  260.0  30.03   6.21  33.84 2010-01-02 13:20:00
# 2     36.14  28.22  72.68   80.0    NaN  17.00  29.21 2010-01-03 12:00:00
# 3     33.80  26.60  74.63  290.0  30.06   5.59  28.53 2010-01-04 13:50:00
# 4     35.60  26.60  69.46  210.0  29.56   6.21  31.62 2010-01-05 15:50:00
# ...     ...    ...    ...    ...    ...    ...    ...                 ...
# 5402  69.80  60.80  73.09  180.0  29.56   6.21  69.80 2024-10-16 12:50:00
# 5403  64.40  50.00  59.50  240.0  29.85   6.21  64.40 2024-10-17 13:50:00
# 5404  62.60  48.20  59.26  220.0  29.91   6.21  62.60 2024-10-18 13:50:00
# 5405  62.60  51.80  67.75  270.0  29.88   6.21  62.60 2024-10-19 13:20:00
# 5406  64.40  60.80  88.09  220.0  29.71   6.21  64.40 2024-10-20 13:20:00
#
# [5407 rows x 8 columns]

# %%
filtered_df['temp_c'] = (filtered_df['tmpf'] - 32) * 5/9

# Drop the old column if needed
filtered_df.drop(columns=['tmpf'], inplace=True)

daily_max_temp=filtered_df
daily_max_temp
# Out:
#        dwpf   relh   drct   alti   vsby   feel                date  temp_c
# 0     25.52  60.14  340.0    NaN  17.00  32.90 2010-01-01 14:00:00     3.4
# 1     30.20  65.16  260.0  30.03   6.21  33.84 2010-01-02 13:20:00     5.0
# 2     28.22  72.68   80.0    NaN  17.00  29.21 2010-01-03 12:00:00     2.3
# 3     26.60  74.63  290.0  30.06   5.59  28.53 2010-01-04 13:50:00     1.0
# 4     26.60  69.46  210.0  29.56   6.21  31.62 2010-01-05 15:50:00     2.0
# ...     ...    ...    ...    ...    ...    ...                 ...     ...
# 5402  60.80  73.09  180.0  29.56   6.21  69.80 2024-10-16 12:50:00    21.0
# 5403  50.00  59.50  240.0  29.85   6.21  64.40 2024-10-17 13:50:00    18.0
# 5404  48.20  59.26  220.0  29.91   6.21  62.60 2024-10-18 13:50:00    17.0
# 5405  51.80  67.75  270.0  29.88   6.21  62.60 2024-10-19 13:20:00    17.0
# 5406  60.80  88.09  220.0  29.71   6.21  64.40 2024-10-20 13:20:00    18.0
#
# [5407 rows x 8 columns]

# %%
percentile_90 = np.percentile(daily_max_temp['temp_c'], 90)
print(f"90th Percentile of max_temp_c: {percentile_90}")
daily_max_temp.drop(columns=['date'], inplace=True)
daily_max_temp
# Out:
# 90th Percentile of max_temp_c: 24.0
#        dwpf   relh   drct   alti   vsby   feel  temp_c
# 0     25.52  60.14  340.0    NaN  17.00  32.90     3.4
# 1     30.20  65.16  260.0  30.03   6.21  33.84     5.0
# 2     28.22  72.68   80.0    NaN  17.00  29.21     2.3
# 3     26.60  74.63  290.0  30.06   5.59  28.53     1.0
# 4     26.60  69.46  210.0  29.56   6.21  31.62     2.0
# ...     ...    ...    ...    ...    ...    ...     ...
# 5402  60.80  73.09  180.0  29.56   6.21  69.80    21.0
# 5403  50.00  59.50  240.0  29.85   6.21  64.40    18.0
# 5404  48.20  59.26  220.0  29.91   6.21  62.60    17.0
# 5405  51.80  67.75  270.0  29.88   6.21  62.60    17.0
# 5406  60.80  88.09  220.0  29.71   6.21  64.40    18.0
#
# [5407 rows x 7 columns]

# %%
daily_max_temp.isna().sum()
# Out:
# dwpf        1
# relh        2
# drct      323
# alti      330
# vsby        3
# feel        3
# temp_c      0
# dtype: int64

# %%
daily_max_temp = daily_max_temp.ffill()

# %%
daily_max_temp['drct'] = daily_max_temp['drct'].fillna(daily_max_temp['drct'].mean()) 
daily_max_temp['alti'] = daily_max_temp['alti'].fillna(daily_max_temp['alti'].mean()) 
daily_max_temp.isna().sum()
# Out:
# dwpf      0
# relh      0
# drct      0
# alti      0
# vsby      0
# feel      0
# temp_c    0
# dtype: int64

# %%
daily_max_temp=daily_max_temp['temp_c']
daily_max_temp
# Out:
# 0        3.4
# 1        5.0
# 2        2.3
# 3        1.0
# 4        2.0
#         ...
# 5402    21.0
# 5403    18.0
# 5404    17.0
# 5405    17.0
# 5406    18.0
# Name: temp_c, Length: 5407, dtype: float64

# %%
daily_max_temp.to_csv('max_temp_c_EGLL_per_day.csv')

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.optimizers import Adam  # Import the Adam optimizer
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import matplotlib.pyplot as plt

def normalize_data(data):
    scaler = MinMaxScaler(feature_range=(-1, 1))
    data_df = data.to_frame()  # converts Series to DataFrame
    scaled_data = scaler.fit_transform(data_df)
    return scaled_data, scaler

def create_sequences(data, sequence_length, prediction_length=3):
    sequences, labels = [], []
    for i in range(len(data) - sequence_length - prediction_length + 1):
        sequences.append(data[i : i + sequence_length])
        labels.append(data[i + sequence_length : i + sequence_length + prediction_length])
    return np.array(sequences), np.array(labels)


# Build and compile LSTM model
def build_lstm_model(input_shape, prediction_length=3, learning_rate=0.001):
    model = Sequential()
    model.add(LSTM(50, return_sequences=False, input_shape=input_shape))
    model.add(Dense(3))  # Output neurons = number of future steps
    
    # Create the Adam optimizer with the specified learning rate
    optimizer = Adam(learning_rate=learning_rate)
    
    # Compile the model with the optimizer and loss function
    model.compile(optimizer=optimizer, loss="mean_squared_error", metrics=["mae"])
    return model


# Plot loss, accuracy, and predictions
def plot_metrics_and_predictions(history, y_test_rescaled, predictions_rescaled, temp_c_index):
    # Loss and Validation Loss Plot
    plt.figure(figsize=(10, 4))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

    # Predictions vs Actuals for temp_c
    plt.figure(figsize=(10, 4))
    plt.plot(predictions_rescaled[:, temp_c_index], label="Predicted temp_c")
    plt.plot(y_test_rescaled[:, temp_c_index], label="Actual temp_c")
    plt.xlabel("Time")
    plt.ylabel("Temperature (temp_c)")
    plt.legend()
    plt.show()


def iterative_forecast_map(model, x_test, days_to_predict, scaler):
    n_samples, seq_len, n_features = x_test.shape
    prediction_dict = {}

    for step in range(1, days_to_predict + 1):
        predictions = []  # Store predictions for this step
        for i in range(n_samples - step + 1):
            # Get the initial sequence for the current sample
            sequence = x_test[i].copy()
            
            # Use `seq_len - step` actual values and the remaining from predictions
            for t in range(step - 1):
                prediction = model.predict(sequence[np.newaxis, :, :])  # Add batch dimension
                prediction = prediction.reshape(1, n_features)  # Ensure correct shape
                sequence = np.vstack((sequence[1:], prediction))  # Update sequence

            # Final prediction for the current step
            final_prediction = model.predict(sequence[np.newaxis, :, :])
            predictions.append(final_prediction[0])

        # Convert predictions to array and inverse transform
        predictions = scaler.inverse_transform(np.array(predictions))

        # Store in dictionary with correct slicing
        prediction_dict[step] = predictions.reshape(-1, 1, n_features)

    return prediction_dict

# %%
from keras.models import load_model

# Initialize variables
sequence_length =7
prediction_length=3
# Make a copy of the original DataFrame to update
updated_data = daily_max_temp.copy()


# Normalize and create sequences
scaled_data, scaler = normalize_data(updated_data)
X, y = create_sequences(scaled_data, sequence_length)

# Train-test split
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]
print(f"data X train shape: {X_train.shape},data X test shape: {X_test.shape}")
print(f"data y train shape: {y_train.shape},data y test shape: {y_test.shape}")

# Train-validation split
val_split = int(len(X_train) * 0.2)
X_val, y_val = X_train[-val_split:], y_train[-val_split:]
X_train, y_train = X_train[:-val_split], y_train[:-val_split]

# Train LSTM model
learning_rate = 0.001  # Specify the desired learning rate
model = build_lstm_model((X_train.shape[1], X_train.shape[2]), learning_rate=learning_rate)
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=300,
    batch_size=32,
    verbose=1)
# Out:
# data X train shape: (4318, 7, 1),data X test shape: (1080, 7, 1)
# data y train shape: (4318, 3, 1),data y test shape: (1080, 3, 1)
# Epoch 1/300
# c:\Users\muham\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0772 - mae: 0.2155 - val_loss: 0.0319 - val_mae: 0.1346
# Epoch 2/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0263 - mae: 0.1271 - val_loss: 0.0305 - val_mae: 0.1315
# Epoch 3/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0253 - mae: 0.1251 - val_loss: 0.0293 - val_mae: 0.1295
# Epoch 4/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0255 - mae: 0.1255 - val_loss: 0.0286 - val_mae: 0.1274
# Epoch 5/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0242 - mae: 0.1224 - val_loss: 0.0277 - val_mae: 0.1255
# Epoch 6/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0234 - mae: 0.1206 - val_loss: 0.0274 - val_mae: 0.1242
# Epoch 7/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0230 - mae: 0.1184 - val_loss: 0.0267 - val_mae: 0.1230
# Epoch 8/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0216 - mae: 0.1151 - val_loss: 0.0258 - val_mae: 0.1211
# Epoch 9/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0216 - mae: 0.1160 - val_loss: 0.0255 - val_mae: 0.1206
# Epoch 10/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0214 - mae: 0.1147 - val_loss: 0.0249 - val_mae: 0.1183
# Epoch 11/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0218 - mae: 0.1156 - val_loss: 0.0245 - val_mae: 0.1179
# Epoch 12/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0210 - mae: 0.1136 - val_loss: 0.0242 - val_mae: 0.1169
# Epoch 13/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1118 - val_loss: 0.0241 - val_mae: 0.1163
# Epoch 14/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0214 - mae: 0.1133 - val_loss: 0.0238 - val_mae: 0.1154
# Epoch 15/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0213 - mae: 0.1134 - val_loss: 0.0240 - val_mae: 0.1163
# Epoch 16/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1122 - val_loss: 0.0238 - val_mae: 0.1157
# Epoch 17/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1119 - val_loss: 0.0235 - val_mae: 0.1154
# Epoch 18/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - mae: 0.1101 - val_loss: 0.0233 - val_mae: 0.1147
# Epoch 19/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208 - mae: 0.1129 - val_loss: 0.0233 - val_mae: 0.1147
# Epoch 20/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0211 - mae: 0.1135 - val_loss: 0.0234 - val_mae: 0.1153
# Epoch 21/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1120 - val_loss: 0.0240 - val_mae: 0.1155
# Epoch 22/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0212 - mae: 0.1135 - val_loss: 0.0236 - val_mae: 0.1151
# Epoch 23/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1112 - val_loss: 0.0232 - val_mae: 0.1145
# Epoch 24/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0211 - mae: 0.1133 - val_loss: 0.0232 - val_mae: 0.1140
# Epoch 25/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0210 - mae: 0.1131 - val_loss: 0.0234 - val_mae: 0.1154
# Epoch 26/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1115 - val_loss: 0.0232 - val_mae: 0.1144
# Epoch 27/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1104 - val_loss: 0.0231 - val_mae: 0.1139
# Epoch 28/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208 - mae: 0.1126 - val_loss: 0.0231 - val_mae: 0.1141
# Epoch 29/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1114 - val_loss: 0.0232 - val_mae: 0.1141
# Epoch 30/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0207 - mae: 0.1123 - val_loss: 0.0232 - val_mae: 0.1141
# Epoch 31/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0216 - mae: 0.1148 - val_loss: 0.0233 - val_mae: 0.1142
# Epoch 32/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0203 - mae: 0.1113 - val_loss: 0.0234 - val_mae: 0.1144
# Epoch 33/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1115 - val_loss: 0.0232 - val_mae: 0.1143
# Epoch 34/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207 - mae: 0.1122 - val_loss: 0.0233 - val_mae: 0.1145
# Epoch 35/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1115 - val_loss: 0.0231 - val_mae: 0.1140
# Epoch 36/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1111 - val_loss: 0.0232 - val_mae: 0.1146
# Epoch 37/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208 - mae: 0.1129 - val_loss: 0.0233 - val_mae: 0.1147
# Epoch 38/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207 - mae: 0.1121 - val_loss: 0.0231 - val_mae: 0.1141
# Epoch 39/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1110 - val_loss: 0.0232 - val_mae: 0.1140
# Epoch 40/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208 - mae: 0.1124 - val_loss: 0.0232 - val_mae: 0.1143
# Epoch 41/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1102 - val_loss: 0.0234 - val_mae: 0.1152
# Epoch 42/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209 - mae: 0.1118 - val_loss: 0.0231 - val_mae: 0.1142
# Epoch 43/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1112 - val_loss: 0.0231 - val_mae: 0.1142
# Epoch 44/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207 - mae: 0.1117 - val_loss: 0.0233 - val_mae: 0.1147
# Epoch 45/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207 - mae: 0.1120 - val_loss: 0.0232 - val_mae: 0.1146
# Epoch 46/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1113 - val_loss: 0.0232 - val_mae: 0.1145
# Epoch 47/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207 - mae: 0.1124 - val_loss: 0.0233 - val_mae: 0.1145
# Epoch 48/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1111 - val_loss: 0.0232 - val_mae: 0.1145
# Epoch 49/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207 - mae: 0.1123 - val_loss: 0.0235 - val_mae: 0.1154
# Epoch 50/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1125 - val_loss: 0.0231 - val_mae: 0.1143
# Epoch 51/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - mae: 0.1097 - val_loss: 0.0232 - val_mae: 0.1147
# Epoch 52/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1105 - val_loss: 0.0232 - val_mae: 0.1149
# Epoch 53/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207 - mae: 0.1123 - val_loss: 0.0232 - val_mae: 0.1147
# Epoch 54/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209 - mae: 0.1129 - val_loss: 0.0232 - val_mae: 0.1144
# Epoch 55/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - mae: 0.1094 - val_loss: 0.0231 - val_mae: 0.1143
# Epoch 56/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1098 - val_loss: 0.0233 - val_mae: 0.1147
# Epoch 57/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1106 - val_loss: 0.0234 - val_mae: 0.1159
# Epoch 58/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209 - mae: 0.1131 - val_loss: 0.0232 - val_mae: 0.1145
# Epoch 59/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0205 - mae: 0.1113 - val_loss: 0.0232 - val_mae: 0.1146
# Epoch 60/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1116 - val_loss: 0.0231 - val_mae: 0.1142
# Epoch 61/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207 - mae: 0.1118 - val_loss: 0.0231 - val_mae: 0.1144
# Epoch 62/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1105 - val_loss: 0.0232 - val_mae: 0.1146
# Epoch 63/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1103 - val_loss: 0.0231 - val_mae: 0.1143
# Epoch 64/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1103 - val_loss: 0.0232 - val_mae: 0.1144
# Epoch 65/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209 - mae: 0.1128 - val_loss: 0.0233 - val_mae: 0.1150
# Epoch 66/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1115 - val_loss: 0.0232 - val_mae: 0.1146
# Epoch 67/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207 - mae: 0.1127 - val_loss: 0.0231 - val_mae: 0.1144
# Epoch 68/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0212 - mae: 0.1135 - val_loss: 0.0233 - val_mae: 0.1147
# Epoch 69/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1104 - val_loss: 0.0237 - val_mae: 0.1159
# Epoch 70/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0210 - mae: 0.1124 - val_loss: 0.0232 - val_mae: 0.1143
# Epoch 71/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1114 - val_loss: 0.0231 - val_mae: 0.1146
# Epoch 72/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1105 - val_loss: 0.0232 - val_mae: 0.1145
# Epoch 73/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207 - mae: 0.1120 - val_loss: 0.0232 - val_mae: 0.1144
# Epoch 74/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1121 - val_loss: 0.0232 - val_mae: 0.1144
# Epoch 75/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1112 - val_loss: 0.0232 - val_mae: 0.1145
# Epoch 76/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0211 - mae: 0.1131 - val_loss: 0.0231 - val_mae: 0.1142
# Epoch 77/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1110 - val_loss: 0.0233 - val_mae: 0.1145
# Epoch 78/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1097 - val_loss: 0.0231 - val_mae: 0.1142
# Epoch 79/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0210 - mae: 0.1129 - val_loss: 0.0232 - val_mae: 0.1144
# Epoch 80/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0211 - mae: 0.1127 - val_loss: 0.0232 - val_mae: 0.1150
# Epoch 81/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207 - mae: 0.1123 - val_loss: 0.0233 - val_mae: 0.1150
# Epoch 82/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1108 - val_loss: 0.0232 - val_mae: 0.1146
# Epoch 83/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1109 - val_loss: 0.0232 - val_mae: 0.1143
# Epoch 84/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1112 - val_loss: 0.0231 - val_mae: 0.1144
# Epoch 85/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1116 - val_loss: 0.0231 - val_mae: 0.1142
# Epoch 86/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1117 - val_loss: 0.0231 - val_mae: 0.1142
# Epoch 87/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209 - mae: 0.1129 - val_loss: 0.0237 - val_mae: 0.1158
# Epoch 88/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1124 - val_loss: 0.0231 - val_mae: 0.1142
# Epoch 89/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1110 - val_loss: 0.0232 - val_mae: 0.1144
# Epoch 90/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1108 - val_loss: 0.0232 - val_mae: 0.1144
# Epoch 91/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1101 - val_loss: 0.0232 - val_mae: 0.1144
# Epoch 92/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208 - mae: 0.1126 - val_loss: 0.0232 - val_mae: 0.1142
# Epoch 93/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1113 - val_loss: 0.0231 - val_mae: 0.1141
# Epoch 94/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1113 - val_loss: 0.0232 - val_mae: 0.1145
# Epoch 95/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0217 - mae: 0.1154 - val_loss: 0.0232 - val_mae: 0.1143
# Epoch 96/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1103 - val_loss: 0.0232 - val_mae: 0.1145
# Epoch 97/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - mae: 0.1098 - val_loss: 0.0231 - val_mae: 0.1143
# Epoch 98/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1106 - val_loss: 0.0233 - val_mae: 0.1145
# Epoch 99/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0214 - mae: 0.1134 - val_loss: 0.0232 - val_mae: 0.1143
# Epoch 100/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209 - mae: 0.1115 - val_loss: 0.0233 - val_mae: 0.1144
# Epoch 101/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1110 - val_loss: 0.0231 - val_mae: 0.1145
# Epoch 102/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0210 - mae: 0.1127 - val_loss: 0.0232 - val_mae: 0.1143
# Epoch 103/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - mae: 0.1097 - val_loss: 0.0232 - val_mae: 0.1142
# Epoch 104/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0199 - mae: 0.1098 - val_loss: 0.0233 - val_mae: 0.1144
# Epoch 105/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0211 - mae: 0.1133 - val_loss: 0.0233 - val_mae: 0.1146
# Epoch 106/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1118 - val_loss: 0.0232 - val_mae: 0.1142
# Epoch 107/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207 - mae: 0.1121 - val_loss: 0.0231 - val_mae: 0.1145
# Epoch 108/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1106 - val_loss: 0.0232 - val_mae: 0.1143
# Epoch 109/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209 - mae: 0.1126 - val_loss: 0.0231 - val_mae: 0.1139
# Epoch 110/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1104 - val_loss: 0.0233 - val_mae: 0.1144
# Epoch 111/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0210 - mae: 0.1129 - val_loss: 0.0231 - val_mae: 0.1141
# Epoch 112/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1113 - val_loss: 0.0231 - val_mae: 0.1143
# Epoch 113/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1118 - val_loss: 0.0231 - val_mae: 0.1143
# Epoch 114/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1102 - val_loss: 0.0231 - val_mae: 0.1142
# Epoch 115/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1119 - val_loss: 0.0233 - val_mae: 0.1144
# Epoch 116/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1108 - val_loss: 0.0231 - val_mae: 0.1145
# Epoch 117/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1101 - val_loss: 0.0231 - val_mae: 0.1140
# Epoch 118/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209 - mae: 0.1125 - val_loss: 0.0232 - val_mae: 0.1141
# Epoch 119/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - mae: 0.1093 - val_loss: 0.0231 - val_mae: 0.1142
# Epoch 120/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207 - mae: 0.1133 - val_loss: 0.0231 - val_mae: 0.1144
# Epoch 121/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1118 - val_loss: 0.0231 - val_mae: 0.1141
# Epoch 122/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208 - mae: 0.1129 - val_loss: 0.0232 - val_mae: 0.1144
# Epoch 123/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1100 - val_loss: 0.0232 - val_mae: 0.1143
# Epoch 124/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1112 - val_loss: 0.0231 - val_mae: 0.1141
# Epoch 125/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1117 - val_loss: 0.0233 - val_mae: 0.1142
# Epoch 126/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1114 - val_loss: 0.0230 - val_mae: 0.1140
# Epoch 127/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1104 - val_loss: 0.0231 - val_mae: 0.1140
# Epoch 128/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - mae: 0.1096 - val_loss: 0.0232 - val_mae: 0.1142
# Epoch 129/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0197 - mae: 0.1098 - val_loss: 0.0231 - val_mae: 0.1140
# Epoch 130/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208 - mae: 0.1118 - val_loss: 0.0231 - val_mae: 0.1140
# Epoch 131/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1107 - val_loss: 0.0231 - val_mae: 0.1139
# Epoch 132/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1108 - val_loss: 0.0231 - val_mae: 0.1141
# Epoch 133/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1108 - val_loss: 0.0232 - val_mae: 0.1140
# Epoch 134/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207 - mae: 0.1120 - val_loss: 0.0232 - val_mae: 0.1141
# Epoch 135/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1116 - val_loss: 0.0231 - val_mae: 0.1142
# Epoch 136/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0211 - mae: 0.1132 - val_loss: 0.0232 - val_mae: 0.1143
# Epoch 137/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1113 - val_loss: 0.0232 - val_mae: 0.1142
# Epoch 138/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1111 - val_loss: 0.0231 - val_mae: 0.1140
# Epoch 139/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0197 - mae: 0.1097 - val_loss: 0.0232 - val_mae: 0.1142
# Epoch 140/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1112 - val_loss: 0.0233 - val_mae: 0.1142
# Epoch 141/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1099 - val_loss: 0.0232 - val_mae: 0.1141
# Epoch 142/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1114 - val_loss: 0.0231 - val_mae: 0.1140
# Epoch 143/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - mae: 0.1099 - val_loss: 0.0231 - val_mae: 0.1139
# Epoch 144/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1107 - val_loss: 0.0231 - val_mae: 0.1141
# Epoch 145/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1109 - val_loss: 0.0232 - val_mae: 0.1142
# Epoch 146/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208 - mae: 0.1129 - val_loss: 0.0231 - val_mae: 0.1139
# Epoch 147/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1099 - val_loss: 0.0232 - val_mae: 0.1142
# Epoch 148/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1126 - val_loss: 0.0233 - val_mae: 0.1153
# Epoch 149/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1119 - val_loss: 0.0230 - val_mae: 0.1137
# Epoch 150/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1101 - val_loss: 0.0232 - val_mae: 0.1144
# Epoch 151/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1124 - val_loss: 0.0230 - val_mae: 0.1139
# Epoch 152/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1109 - val_loss: 0.0230 - val_mae: 0.1139
# Epoch 153/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1116 - val_loss: 0.0230 - val_mae: 0.1140
# Epoch 154/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209 - mae: 0.1126 - val_loss: 0.0231 - val_mae: 0.1140
# Epoch 155/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1104 - val_loss: 0.0232 - val_mae: 0.1140
# Epoch 156/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1104 - val_loss: 0.0230 - val_mae: 0.1139
# Epoch 157/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0211 - mae: 0.1132 - val_loss: 0.0233 - val_mae: 0.1143
# Epoch 158/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1118 - val_loss: 0.0231 - val_mae: 0.1144
# Epoch 159/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1109 - val_loss: 0.0230 - val_mae: 0.1137
# Epoch 160/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208 - mae: 0.1121 - val_loss: 0.0231 - val_mae: 0.1139
# Epoch 161/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208 - mae: 0.1118 - val_loss: 0.0230 - val_mae: 0.1139
# Epoch 162/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1108 - val_loss: 0.0231 - val_mae: 0.1139
# Epoch 163/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1108 - val_loss: 0.0231 - val_mae: 0.1138
# Epoch 164/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1117 - val_loss: 0.0233 - val_mae: 0.1142
# Epoch 165/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1108 - val_loss: 0.0232 - val_mae: 0.1141
# Epoch 166/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1122 - val_loss: 0.0230 - val_mae: 0.1138
# Epoch 167/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1119 - val_loss: 0.0230 - val_mae: 0.1138
# Epoch 168/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1115 - val_loss: 0.0230 - val_mae: 0.1139
# Epoch 169/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1116 - val_loss: 0.0230 - val_mae: 0.1140
# Epoch 170/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0214 - mae: 0.1142 - val_loss: 0.0232 - val_mae: 0.1141
# Epoch 171/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0210 - mae: 0.1128 - val_loss: 0.0230 - val_mae: 0.1138
# Epoch 172/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - mae: 0.1097 - val_loss: 0.0230 - val_mae: 0.1138
# Epoch 173/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - mae: 0.1100 - val_loss: 0.0232 - val_mae: 0.1139
# Epoch 174/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1115 - val_loss: 0.0231 - val_mae: 0.1140
# Epoch 175/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0211 - mae: 0.1129 - val_loss: 0.0230 - val_mae: 0.1137
# Epoch 176/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1119 - val_loss: 0.0231 - val_mae: 0.1139
# Epoch 177/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1105 - val_loss: 0.0231 - val_mae: 0.1139
# Epoch 178/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1104 - val_loss: 0.0232 - val_mae: 0.1143
# Epoch 179/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - mae: 0.1104 - val_loss: 0.0231 - val_mae: 0.1138
# Epoch 180/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1108 - val_loss: 0.0230 - val_mae: 0.1136
# Epoch 181/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208 - mae: 0.1120 - val_loss: 0.0230 - val_mae: 0.1137
# Epoch 182/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - mae: 0.1104 - val_loss: 0.0232 - val_mae: 0.1144
# Epoch 183/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209 - mae: 0.1125 - val_loss: 0.0230 - val_mae: 0.1137
# Epoch 184/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1108 - val_loss: 0.0232 - val_mae: 0.1140
# Epoch 185/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208 - mae: 0.1122 - val_loss: 0.0230 - val_mae: 0.1135
# Epoch 186/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0193 - mae: 0.1086 - val_loss: 0.0231 - val_mae: 0.1139
# Epoch 187/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1105 - val_loss: 0.0232 - val_mae: 0.1140
# Epoch 188/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1109 - val_loss: 0.0232 - val_mae: 0.1141
# Epoch 189/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1115 - val_loss: 0.0230 - val_mae: 0.1136
# Epoch 190/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1105 - val_loss: 0.0230 - val_mae: 0.1138
# Epoch 191/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0213 - mae: 0.1135 - val_loss: 0.0230 - val_mae: 0.1141
# Epoch 192/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207 - mae: 0.1123 - val_loss: 0.0230 - val_mae: 0.1138
# Epoch 193/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1106 - val_loss: 0.0230 - val_mae: 0.1139
# Epoch 194/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1128 - val_loss: 0.0231 - val_mae: 0.1136
# Epoch 195/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1096 - val_loss: 0.0230 - val_mae: 0.1137
# Epoch 196/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1121 - val_loss: 0.0230 - val_mae: 0.1136
# Epoch 197/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208 - mae: 0.1125 - val_loss: 0.0230 - val_mae: 0.1138
# Epoch 198/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1118 - val_loss: 0.0231 - val_mae: 0.1143
# Epoch 199/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1119 - val_loss: 0.0231 - val_mae: 0.1139
# Epoch 200/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - mae: 0.1101 - val_loss: 0.0233 - val_mae: 0.1141
# Epoch 201/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1112 - val_loss: 0.0230 - val_mae: 0.1135
# Epoch 202/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1105 - val_loss: 0.0230 - val_mae: 0.1136
# Epoch 203/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1112 - val_loss: 0.0230 - val_mae: 0.1137
# Epoch 204/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1117 - val_loss: 0.0231 - val_mae: 0.1137
# Epoch 205/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1113 - val_loss: 0.0230 - val_mae: 0.1138
# Epoch 206/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1109 - val_loss: 0.0232 - val_mae: 0.1137
# Epoch 207/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1104 - val_loss: 0.0230 - val_mae: 0.1137
# Epoch 208/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - mae: 0.1099 - val_loss: 0.0230 - val_mae: 0.1136
# Epoch 209/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1109 - val_loss: 0.0232 - val_mae: 0.1136
# Epoch 210/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1111 - val_loss: 0.0230 - val_mae: 0.1137
# Epoch 211/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1103 - val_loss: 0.0230 - val_mae: 0.1139
# Epoch 212/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1106 - val_loss: 0.0231 - val_mae: 0.1137
# Epoch 213/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1117 - val_loss: 0.0232 - val_mae: 0.1141
# Epoch 214/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1122 - val_loss: 0.0233 - val_mae: 0.1145
# Epoch 215/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0196 - mae: 0.1089 - val_loss: 0.0232 - val_mae: 0.1139
# Epoch 216/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1106 - val_loss: 0.0233 - val_mae: 0.1140
# Epoch 217/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1109 - val_loss: 0.0230 - val_mae: 0.1136
# Epoch 218/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1109 - val_loss: 0.0232 - val_mae: 0.1144
# Epoch 219/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1104 - val_loss: 0.0231 - val_mae: 0.1136
# Epoch 220/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1116 - val_loss: 0.0230 - val_mae: 0.1135
# Epoch 221/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - mae: 0.1099 - val_loss: 0.0231 - val_mae: 0.1138
# Epoch 222/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0210 - mae: 0.1127 - val_loss: 0.0231 - val_mae: 0.1137
# Epoch 223/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1106 - val_loss: 0.0233 - val_mae: 0.1143
# Epoch 224/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1113 - val_loss: 0.0230 - val_mae: 0.1137
# Epoch 225/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1114 - val_loss: 0.0231 - val_mae: 0.1137
# Epoch 226/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0196 - mae: 0.1088 - val_loss: 0.0231 - val_mae: 0.1140
# Epoch 227/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1116 - val_loss: 0.0232 - val_mae: 0.1140
# Epoch 228/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - mae: 0.1103 - val_loss: 0.0231 - val_mae: 0.1137
# Epoch 229/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1108 - val_loss: 0.0234 - val_mae: 0.1145
# Epoch 230/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207 - mae: 0.1122 - val_loss: 0.0230 - val_mae: 0.1135
# Epoch 231/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1113 - val_loss: 0.0232 - val_mae: 0.1140
# Epoch 232/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209 - mae: 0.1127 - val_loss: 0.0231 - val_mae: 0.1138
# Epoch 233/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208 - mae: 0.1123 - val_loss: 0.0231 - val_mae: 0.1136
# Epoch 234/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1109 - val_loss: 0.0232 - val_mae: 0.1139
# Epoch 235/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0197 - mae: 0.1094 - val_loss: 0.0232 - val_mae: 0.1140
# Epoch 236/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0195 - mae: 0.1094 - val_loss: 0.0231 - val_mae: 0.1140
# Epoch 237/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1104 - val_loss: 0.0231 - val_mae: 0.1137
# Epoch 238/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1112 - val_loss: 0.0232 - val_mae: 0.1143
# Epoch 239/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1112 - val_loss: 0.0231 - val_mae: 0.1139
# Epoch 240/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1110 - val_loss: 0.0231 - val_mae: 0.1139
# Epoch 241/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1111 - val_loss: 0.0231 - val_mae: 0.1139
# Epoch 242/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1119 - val_loss: 0.0231 - val_mae: 0.1139
# Epoch 243/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1112 - val_loss: 0.0232 - val_mae: 0.1139
# Epoch 244/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - mae: 0.1099 - val_loss: 0.0232 - val_mae: 0.1144
# Epoch 245/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - mae: 0.1101 - val_loss: 0.0232 - val_mae: 0.1137
# Epoch 246/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1102 - val_loss: 0.0233 - val_mae: 0.1138
# Epoch 247/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1105 - val_loss: 0.0232 - val_mae: 0.1138
# Epoch 248/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1115 - val_loss: 0.0236 - val_mae: 0.1144
# Epoch 249/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1111 - val_loss: 0.0234 - val_mae: 0.1143
# Epoch 250/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - mae: 0.1103 - val_loss: 0.0232 - val_mae: 0.1142
# Epoch 251/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - mae: 0.1093 - val_loss: 0.0232 - val_mae: 0.1138
# Epoch 252/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1097 - val_loss: 0.0233 - val_mae: 0.1143
# Epoch 253/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1113 - val_loss: 0.0231 - val_mae: 0.1140
# Epoch 254/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1113 - val_loss: 0.0232 - val_mae: 0.1141
# Epoch 255/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - mae: 0.1092 - val_loss: 0.0232 - val_mae: 0.1143
# Epoch 256/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1109 - val_loss: 0.0234 - val_mae: 0.1145
# Epoch 257/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - mae: 0.1094 - val_loss: 0.0233 - val_mae: 0.1142
# Epoch 258/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - mae: 0.1113 - val_loss: 0.0232 - val_mae: 0.1141
# Epoch 259/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - mae: 0.1100 - val_loss: 0.0234 - val_mae: 0.1143
# Epoch 260/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0210 - mae: 0.1128 - val_loss: 0.0232 - val_mae: 0.1140
# Epoch 261/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - mae: 0.1098 - val_loss: 0.0232 - val_mae: 0.1139
# Epoch 262/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - mae: 0.1096 - val_loss: 0.0233 - val_mae: 0.1144
# Epoch 263/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - mae: 0.1099 - val_loss: 0.0233 - val_mae: 0.1145
# Epoch 264/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0197 - mae: 0.1097 - val_loss: 0.0235 - val_mae: 0.1149
# Epoch 265/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1108 - val_loss: 0.0234 - val_mae: 0.1144
# Epoch 266/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - mae: 0.1096 - val_loss: 0.0233 - val_mae: 0.1142
# Epoch 267/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0192 - mae: 0.1087 - val_loss: 0.0235 - val_mae: 0.1145
# Epoch 268/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1114 - val_loss: 0.0237 - val_mae: 0.1150
# Epoch 269/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1119 - val_loss: 0.0234 - val_mae: 0.1144
# Epoch 270/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1111 - val_loss: 0.0238 - val_mae: 0.1152
# Epoch 271/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1111 - val_loss: 0.0236 - val_mae: 0.1153
# Epoch 272/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - mae: 0.1098 - val_loss: 0.0236 - val_mae: 0.1150
# Epoch 273/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1117 - val_loss: 0.0236 - val_mae: 0.1146
# Epoch 274/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1106 - val_loss: 0.0236 - val_mae: 0.1149
# Epoch 275/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1104 - val_loss: 0.0234 - val_mae: 0.1146
# Epoch 276/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1113 - val_loss: 0.0238 - val_mae: 0.1153
# Epoch 277/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0194 - mae: 0.1083 - val_loss: 0.0236 - val_mae: 0.1151
# Epoch 278/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - mae: 0.1103 - val_loss: 0.0239 - val_mae: 0.1158
# Epoch 279/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1098 - val_loss: 0.0234 - val_mae: 0.1144
# Epoch 280/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1121 - val_loss: 0.0239 - val_mae: 0.1156
# Epoch 281/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - mae: 0.1112 - val_loss: 0.0235 - val_mae: 0.1149
# Epoch 282/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - mae: 0.1116 - val_loss: 0.0236 - val_mae: 0.1149
# Epoch 283/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0194 - mae: 0.1097 - val_loss: 0.0237 - val_mae: 0.1147
# Epoch 284/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - mae: 0.1103 - val_loss: 0.0236 - val_mae: 0.1149
# Epoch 285/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1116 - val_loss: 0.0235 - val_mae: 0.1147
# Epoch 286/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - mae: 0.1098 - val_loss: 0.0237 - val_mae: 0.1149
# Epoch 287/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - mae: 0.1094 - val_loss: 0.0236 - val_mae: 0.1148
# Epoch 288/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0196 - mae: 0.1097 - val_loss: 0.0236 - val_mae: 0.1148
# Epoch 289/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1106 - val_loss: 0.0235 - val_mae: 0.1146
# Epoch 290/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0196 - mae: 0.1097 - val_loss: 0.0236 - val_mae: 0.1149
# Epoch 291/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - mae: 0.1116 - val_loss: 0.0238 - val_mae: 0.1151
# Epoch 292/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - mae: 0.1103 - val_loss: 0.0238 - val_mae: 0.1155
# Epoch 293/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0193 - mae: 0.1087 - val_loss: 0.0238 - val_mae: 0.1153
# Epoch 294/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0192 - mae: 0.1079 - val_loss: 0.0239 - val_mae: 0.1153
# Epoch 295/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209 - mae: 0.1132 - val_loss: 0.0239 - val_mae: 0.1155
# Epoch 296/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0192 - mae: 0.1079 - val_loss: 0.0238 - val_mae: 0.1151
# Epoch 297/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208 - mae: 0.1126 - val_loss: 0.0239 - val_mae: 0.1156
# Epoch 298/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - mae: 0.1101 - val_loss: 0.0238 - val_mae: 0.1154
# Epoch 299/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - mae: 0.1110 - val_loss: 0.0239 - val_mae: 0.1156
# Epoch 300/300
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0197 - mae: 0.1097 - val_loss: 0.0238 - val_mae: 0.1150

# %%
y_pred = model.predict(X_test)
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# Predict
y_pred = model.predict(X_test)  # Shape: (1080, 3)
y_test = y_test.reshape(-1, 3)  # Ensure it's (1080, 3)

# Inverse transform
y_pred_flat = y_pred.reshape(-1, 1)
y_test_flat = y_test.reshape(-1, 1)

y_pred_inv = scaler.inverse_transform(y_pred_flat).reshape(-1, 3)
y_test_inv = scaler.inverse_transform(y_test_flat).reshape(-1, 3)
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
for day in range(prediction_length):
    plt.figure(figsize=(10, 4))
    plt.plot(y_test_inv[:, day], label=f'True Day {day+1}')
    plt.plot(y_pred_inv[:, day], label=f'Predicted Day {day+1}')
    plt.xlabel('Test Sequence Index')
    plt.ylabel('Temperature (°C)')
    plt.title(f'Temperature Prediction for Day {day+1} After {sequence_length}-Day Input')
    plt.legend()
    plt.tight_layout()
    plt.show()

# --- Step 6: Difference bar chart ---

diff = y_test_inv - y_pred_inv
for day in range(prediction_length):
    plt.figure(figsize=(10, 4))
    colors = np.where(diff[:, day] >= 0, 'green', 'red')
    for i in range(len(diff)):
        plt.bar(i, diff[i, day], color=colors[i])
    plt.xlabel('Test Sequence Index')
    plt.ylabel(f'Difference (Actual - Predicted) for Day {day+1}')
    plt.title(f'Difference in Temperature Prediction for Day {day+1}')
    plt.tight_layout()
    plt.show()

# --- Step 7: Evaluation metrics ---
r2_scores = []
mse_scores = []
mae_scores = []
rmse_scores = []

for day in range(prediction_length):
    r2 = r2_score(y_test_inv[:, day], y_pred_inv[:, day])
    mse = mean_squared_error(y_test_inv[:, day], y_pred_inv[:, day])
    mae = mean_absolute_error(y_test_inv[:, day], y_pred_inv[:, day])
    rmse = np.sqrt(mse)

    r2_scores.append(r2)
    mse_scores.append(mse)
    mae_scores.append(mae)
    rmse_scores.append(rmse)

    print(f"\nMetrics for Day {day+1} Prediction:")
    print(f"R² Score: {r2:.4f}")
    print(f"Mean Squared Error (MSE): {mse:.4f}")
    print(f"Mean Absolute Error (MAE): {mae:.4f}")
    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
# Out:
# Metrics for Day 1 Prediction:
# R² Score: 0.8592
# Mean Squared Error (MSE): 5.7140
# Mean Absolute Error (MAE): 1.8859
# Root Mean Squared Error (RMSE): 2.3904
#
# Metrics for Day 2 Prediction:
# R² Score: 0.7847
# Mean Squared Error (MSE): 8.7300
# Mean Absolute Error (MAE): 2.3304
# Root Mean Squared Error (RMSE): 2.9547
#
# Metrics for Day 3 Prediction:
# R² Score: 0.7442
# Mean Squared Error (MSE): 10.3645
# Mean Absolute Error (MAE): 2.5254
# Root Mean Squared Error (RMSE): 3.2194

# %%
# Save the trained model
model.save('model_seq7_pre3.keras')

# Save the training history
np.save('history_seq7_pre3.npy', history.history)

print("Model and training history saved successfully.")
# Out:
# Model and training history saved successfully.

# %%
import matplotlib.pyplot as plt

# Metrics data
days = ['Day 1', 'Day 2', 'Day 3']


# Create 1x4 subplots
fig, axes = plt.subplots(1, 4, figsize=(20, 4))

# R² Score (zoomed in between 0.8 and 1.0)
axes[0].plot(days, r2_scores, marker='o', color='green')
axes[0].set_title('R² Score')
axes[0].grid(True)

# MSE
axes[1].plot(days, mse_scores, marker='o', color='blue')
axes[1].set_title('Mean Squared Error (MSE)')
axes[1].grid(True)

# MAE
axes[2].plot(days, mae_scores, marker='o', color='orange')
axes[2].set_title('Mean Absolute Error (MAE)')
axes[2].grid(True)

# RMSE
axes[3].plot(days, rmse_scores, marker='o', color='red')
axes[3].set_title('Root Mean Squared Error (RMSE)')
axes[3].grid(True)

# Shared axis labels
for ax in axes:
    ax.set_xlabel('Prediction Day')
    ax.set_ylabel('Value')

plt.suptitle('Prediction Metrics Over 3 Days', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 50)             │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 3)              │           153 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,661 (123.68 KB)
#  Trainable params: 10,553 (41.22 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 21,108 (82.46 KB)
