# %%
from tensorflow.keras.models import load_model

# Load your saved LSTM model
model = load_model("model_seq7_pre3.keras")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from tensorflow.keras.models import load_model
#       3 # Load your saved LSTM model
#       4 model = load_model("model_seq7_pre3.keras")
#
# File c:\Users\muham\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\__init__.py:468
#     466     importlib.import_module("tf_keras.src.optimizers")
#     467   else:
# --> 468     importlib.import_module("keras.src.optimizers")
#     469 except (ImportError, AttributeError):
#     470   pass
#
# File c:\Users\muham\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# ...
